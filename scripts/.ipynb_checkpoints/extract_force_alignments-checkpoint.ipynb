# %% [markdown]
# ### Code to extract ground truth segmentation for TIMIT

# %%
import os
from pathlib import Path

def read_timit_phone_alignment(phn_file, frame_rate=0.02, sr=16e3):
    starts = []
    ends = []
    labels = []
    with open(phn_file, 'r') as f:
        for line in f:
            start, end, label = line.split()
            start = int(start) // int(frame_rate * sr)
            end = int(end) // int(frame_rate * sr)
            labels.extend([label for _ in range(start, end)])
    return labels

def extract_timit_phone_alignments(manifest_dir, align_dir, out_dir,  split):
    manifest_dir = Path(manifest_dir)
    out_dir = Path(out_dir)
    if not out_dir.exists():
        out_dir.mkdir(parents=True, exist_ok=True)
    align_dict = {}
    for root, dir_list, file_list in os.walk(align_dir):
        root = Path(root)
        for fn in file_list:
            if fn.endswith('.PHN'):
                fn = root / Path(fn)
                spk_id = fn.name.split(".")[0]
                file_id = f'{fn.parent.name}_{spk_id}'
                align_dict[file_id] = fn 
    
    vocab = ['h#']
    with open(manifest_dir / f'{split}.tsv', 'r') as f_tsv,\
        open(manifest_dir / f'{split}.lengths', 'r') as f_len,\
        open(out_dir / f'{split}.src', 'w') as f_src,\
        open(out_dir / f'{split}.src.txt', 'w') as f_src_txt:
        lines = f_tsv.read().strip().split('\n')
        sizes = list(map(int, f_len.read().strip().split('\n')))
        _ = lines.pop(0)
        for l, s in zip(lines, sizes):
            filepath = l.split('\t')[0]
            file_id = Path(filepath).name.split(".")[0]
            print(file_id)  # XXX
            ali_file = align_dict[file_id]
            labels = read_timit_phone_alignment(ali_file)
            int_labels = []
            print(f'True length: {s}, alignment length: {len(labels)}')
            for y in labels:
                if not y in vocab:
                    vocab.append(y)
                int_labels.append(vocab.index(y))
            if s > len(labels):
                gap = s - len(labels)
                labels.extend(['h#']*gap)
                int_labels.extend([0]*gap)
            elif s < len(labels):
                labels = labels[:s]
                int_labels = int_labels[:s]
            assert len(int_labels) == s
            f_src_txt.write(" ".join(labels)+"\n")
            f_src.write(" ".join(list(map(str, int_labels)))+"\n")
    print(f'Number of phonemes: {len(vocab)}') 
    print(vocab)

# %%
split = 'valid'
align_split = 'TEST' #split.upper()
manifest_dir = '/home/lwang114/workplace/fall2022/UnsupSpeech2Sign/manifest/timit_phn/matched/feat'
align_dir = f'/home/hertin/data/timit/TIMIT/{align_split}'
out_dir = '/home/lwang114/workplace/fall2022/UnsupSpeech2Sign/manifest/timit_phn/matched/feat/CLUS60'

extract_timit_phone_alignments(manifest_dir, align_dir, out_dir, split)
# Out:
# FADG0_SI1279
# True length: 90, alignment length: 90
# FADG0_SI1909
# True length: 139, alignment length: 139
# FADG0_SI649
# True length: 230, alignment length: 230
# FADG0_SX109
# True length: 152, alignment length: 152
# FADG0_SX199
# True length: 188, alignment length: 188
# FADG0_SX19
# True length: 135, alignment length: 135
# FADG0_SX289
# True length: 145, alignment length: 145
# FADG0_SX379
# True length: 133, alignment length: 133
# FAKS0_SI1573
# True length: 248, alignment length: 248
# FAKS0_SI2203
# True length: 175, alignment length: 175
# FAKS0_SI943
# True length: 187, alignment length: 187
# FAKS0_SX133
# True length: 165, alignment length: 165
# FAKS0_SX223
# True length: 154, alignment length: 154
# FAKS0_SX313
# True length: 176, alignment length: 176
# FAKS0_SX403
# True length: 167, alignment length: 167
# FAKS0_SX43
# True length: 122, alignment length: 122
# FCAL1_SI1403
# True length: 241, alignment length: 241
# FCAL1_SI2033
# True length: 166, alignment length: 166
# FCAL1_SI773
# True length: 145, alignment length: 145
# FCAL1_SX143
# True length: 129, alignment length: 129
# FCAL1_SX233
# True length: 127, alignment length: 127
# FCAL1_SX323
# True length: 130, alignment length: 130
# FCAL1_SX413
# True length: 155, alignment length: 155
# FCAL1_SX53
# True length: 142, alignment length: 142
# FCMH0_SI1454
# True length: 256, alignment length: 256
# FCMH0_SI2084
# True length: 75, alignment length: 76
# FCMH0_SI824
# True length: 241, alignment length: 241
# FCMH0_SX104
# True length: 98, alignment length: 98
# FCMH0_SX14
# True length: 149, alignment length: 149
# FCMH0_SX194
# True length: 91, alignment length: 91
# FCMH0_SX284
# True length: 160, alignment length: 160
# FCMH0_SX374
# True length: 108, alignment length: 108
# FDAC1_SI1474
# True length: 220, alignment length: 220
# FDAC1_SI2104
# True length: 229, alignment length: 229
# FDAC1_SI844
# True length: 371, alignment length: 371
# FDAC1_SX124
# True length: 136, alignment length: 136
# FDAC1_SX214
# True length: 221, alignment length: 221
# FDAC1_SX304
# True length: 210, alignment length: 210
# FDAC1_SX34
# True length: 201, alignment length: 201
# FDAC1_SX394
# True length: 192, alignment length: 192
# FDMS0_SI1218
# True length: 128, alignment length: 128
# FDMS0_SI1502
# True length: 196, alignment length: 196
# FDMS0_SI1848
# True length: 135, alignment length: 135
# FDMS0_SX138
# True length: 148, alignment length: 148
# FDMS0_SX228
# True length: 123, alignment length: 124
# FDMS0_SX318
# True length: 124, alignment length: 125
# FDMS0_SX408
# True length: 124, alignment length: 125
# FDMS0_SX48
# True length: 130, alignment length: 131
# FDRW0_SI1283
# True length: 250, alignment length: 251
# FDRW0_SI1423
# True length: 119, alignment length: 119
# FDRW0_SI653
# True length: 149, alignment length: 149
# FDRW0_SX113
# True length: 203, alignment length: 203
# FDRW0_SX203
# True length: 161, alignment length: 161
# FDRW0_SX23
# True length: 148, alignment length: 149
# FDRW0_SX293
# True length: 147, alignment length: 147
# FDRW0_SX383
# True length: 138, alignment length: 139
# FEDW0_SI1084
# True length: 287, alignment length: 287
# FEDW0_SI1653
# True length: 83, alignment length: 83
# FEDW0_SI1714
# True length: 165, alignment length: 165
# FEDW0_SX184
# True length: 183, alignment length: 183
# FEDW0_SX274
# True length: 168, alignment length: 168
# FEDW0_SX364
# True length: 316, alignment length: 316
# FEDW0_SX4
# True length: 165, alignment length: 165
# FEDW0_SX94
# True length: 169, alignment length: 169
# FGJD0_SI1179
# True length: 102, alignment length: 102
# FGJD0_SI549
# True length: 257, alignment length: 257
# FGJD0_SI818
# True length: 277, alignment length: 277
# FGJD0_SX189
# True length: 162, alignment length: 163
# FGJD0_SX279
# True length: 193, alignment length: 193
# FGJD0_SX369
# True length: 141, alignment length: 141
# FGJD0_SX99
# True length: 162, alignment length: 162
# FGJD0_SX9
# True length: 112, alignment length: 112
# FJEM0_SI1264
# True length: 172, alignment length: 172
# FJEM0_SI1894
# True length: 146, alignment length: 147
# FJEM0_SI634
# True length: 304, alignment length: 304
# FJEM0_SX184
# True length: 145, alignment length: 145
# FJEM0_SX274
# True length: 195, alignment length: 196
# FJEM0_SX364
# True length: 289, alignment length: 289
# FJEM0_SX4
# True length: 150, alignment length: 150
# FJEM0_SX94
# True length: 160, alignment length: 160
# FJMG0_SI1181
# True length: 219, alignment length: 220
# FJMG0_SI1811
# True length: 148, alignment length: 148
# FJMG0_SI551
# True length: 164, alignment length: 164
# FJMG0_SX101
# True length: 225, alignment length: 225
# FJMG0_SX11
# True length: 109, alignment length: 110
# FJMG0_SX191
# True length: 162, alignment length: 163
# FJMG0_SX281
# True length: 194, alignment length: 194
# FJMG0_SX371
# True length: 180, alignment length: 180
# FJSJ0_SI1484
# True length: 138, alignment length: 139
# FJSJ0_SI2114
# True length: 127, alignment length: 128
# FJSJ0_SI854
# True length: 127, alignment length: 128
# FJSJ0_SX134
# True length: 140, alignment length: 140
# FJSJ0_SX224
# True length: 92, alignment length: 92
# FJSJ0_SX314
# True length: 159, alignment length: 160
# FJSJ0_SX404
# True length: 120, alignment length: 120
# FJSJ0_SX44
# True length: 141, alignment length: 141
# FKMS0_SI1490
# True length: 134, alignment length: 134
# FKMS0_SI2120
# True length: 206, alignment length: 206
# FKMS0_SI860
# True length: 217, alignment length: 218
# FKMS0_SX140
# True length: 140, alignment length: 140
# FKMS0_SX230
# True length: 187, alignment length: 187
# FKMS0_SX320
# True length: 152, alignment length: 152
# FKMS0_SX410
# True length: 123, alignment length: 123
# FKMS0_SX50
# True length: 149, alignment length: 150
# FMAH0_SI1289
# True length: 92, alignment length: 92
# FMAH0_SI1919
# True length: 167, alignment length: 167
# FMAH0_SI659
# True length: 222, alignment length: 223
# FMAH0_SX119
# True length: 136, alignment length: 136
# FMAH0_SX209
# True length: 139, alignment length: 139
# FMAH0_SX299
# True length: 171, alignment length: 171
# FMAH0_SX29
# True length: 117, alignment length: 117
# FMAH0_SX389
# True length: 134, alignment length: 134
# FMML0_SI1040
# True length: 170, alignment length: 170
# FMML0_SI1670
# True length: 146, alignment length: 146
# FMML0_SI2300
# True length: 146, alignment length: 147
# FMML0_SX140
# True length: 179, alignment length: 180
# FMML0_SX230
# True length: 185, alignment length: 185
# FMML0_SX320
# True length: 158, alignment length: 158
# FMML0_SX410
# True length: 133, alignment length: 133
# FMML0_SX50
# True length: 159, alignment length: 159
# FNMR0_SI1399
# True length: 238, alignment length: 238
# FNMR0_SI2029
# True length: 143, alignment length: 143
# FNMR0_SI769
# True length: 140, alignment length: 130
# FNMR0_SX139
# True length: 147, alignment length: 148
# FNMR0_SX229
# True length: 86, alignment length: 86
# FNMR0_SX319
# True length: 152, alignment length: 152
# FNMR0_SX409
# True length: 167, alignment length: 167
# FNMR0_SX49
# True length: 144, alignment length: 144
# FREW0_SI1030
# True length: 74, alignment length: 75
# FREW0_SI1280
# True length: 161, alignment length: 161
# FREW0_SI1910
# True length: 103, alignment length: 103
# FREW0_SX110
# True length: 125, alignment length: 125
# FREW0_SX200
# True length: 114, alignment length: 114
# FREW0_SX20
# True length: 123, alignment length: 123
# FREW0_SX290
# True length: 163, alignment length: 163
# FREW0_SX380
# True length: 96, alignment length: 96
# FSEM0_SI1198
# True length: 133, alignment length: 133
# FSEM0_SI1828
# True length: 254, alignment length: 254
# FSEM0_SI568
# True length: 186, alignment length: 186
# FSEM0_SX118
# True length: 118, alignment length: 118
# FSEM0_SX208
# True length: 155, alignment length: 155
# FSEM0_SX28
# True length: 150, alignment length: 151
# FSEM0_SX298
# True length: 153, alignment length: 153
# FSEM0_SX388
# True length: 197, alignment length: 197
# MAJC0_SI1946
# True length: 129, alignment length: 130
# MAJC0_SI2095
# True length: 123, alignment length: 123
# MAJC0_SI835
# True length: 214, alignment length: 214
# MAJC0_SX115
# True length: 145, alignment length: 145
# MAJC0_SX205
# True length: 171, alignment length: 171
# MAJC0_SX25
# True length: 97, alignment length: 97
# MAJC0_SX295
# True length: 174, alignment length: 174
# MAJC0_SX385
# True length: 112, alignment length: 112
# MBDG0_SI1463
# True length: 140, alignment length: 140
# MBDG0_SI2093
# True length: 191, alignment length: 191
# MBDG0_SI833
# True length: 123, alignment length: 123
# MBDG0_SX113
# True length: 112, alignment length: 112
# MBDG0_SX203
# True length: 107, alignment length: 107
# MBDG0_SX23
# True length: 125, alignment length: 125
# MBDG0_SX293
# True length: 169, alignment length: 170
# MBDG0_SX383
# True length: 126, alignment length: 126
# MBNS0_SI1220
# True length: 140, alignment length: 140
# MBNS0_SI1850
# True length: 88, alignment length: 88
# MBNS0_SI590
# True length: 202, alignment length: 202
# MBNS0_SX140
# True length: 157, alignment length: 157
# MBNS0_SX230
# True length: 160, alignment length: 160
# MBNS0_SX320
# True length: 155, alignment length: 155
# MBNS0_SX410
# True length: 132, alignment length: 132
# MBNS0_SX50
# True length: 155, alignment length: 155
# MBWM0_SI1304
# True length: 152, alignment length: 152
# MBWM0_SI1934
# True length: 54, alignment length: 54
# MBWM0_SI674
# True length: 230, alignment length: 230
# MBWM0_SX134
# True length: 161, alignment length: 162
# MBWM0_SX224
# True length: 80, alignment length: 80
# MBWM0_SX314
# True length: 160, alignment length: 160
# MBWM0_SX404
# True length: 146, alignment length: 146
# MBWM0_SX44
# True length: 136, alignment length: 136
# MCSH0_SI1549
# True length: 103, alignment length: 103
# MCSH0_SI2179
# True length: 110, alignment length: 110
# MCSH0_SI919
# True length: 249, alignment length: 249
# MCSH0_SX109
# True length: 169, alignment length: 169
# MCSH0_SX199
# True length: 207, alignment length: 207
# MCSH0_SX19
# True length: 148, alignment length: 148
# MCSH0_SX289
# True length: 176, alignment length: 176
# MCSH0_SX379
# True length: 136, alignment length: 136
# MDLF0_SI1583
# True length: 128, alignment length: 128
# MDLF0_SI2213
# True length: 97, alignment length: 97
# MDLF0_SI953
# True length: 231, alignment length: 231
# MDLF0_SX143
# True length: 144, alignment length: 144
# MDLF0_SX233
# True length: 118, alignment length: 118
# MDLF0_SX323
# True length: 138, alignment length: 138
# MDLF0_SX413
# True length: 156, alignment length: 156
# MDLF0_SX53
# True length: 152, alignment length: 152
# MDLS0_SI1628
# True length: 145, alignment length: 145
# MDLS0_SI2258
# True length: 75, alignment length: 76
# MDLS0_SI998
# True length: 76, alignment length: 76
# MDLS0_SX188
# True length: 108, alignment length: 108
# MDLS0_SX278
# True length: 163, alignment length: 163
# MDLS0_SX368
# True length: 162, alignment length: 163
# MDLS0_SX8
# True length: 104, alignment length: 104
# MDLS0_SX98
# True length: 85, alignment length: 85
# MDVC0_SI2174
# True length: 109, alignment length: 109
# MDVC0_SI2196
# True length: 222, alignment length: 222
# MDVC0_SI936
# True length: 176, alignment length: 176
# MDVC0_SX126
# True length: 130, alignment length: 131
# MDVC0_SX216
# True length: 121, alignment length: 122
# MDVC0_SX306
# True length: 129, alignment length: 129
# MDVC0_SX36
# True length: 179, alignment length: 180
# MDVC0_SX396
# True length: 199, alignment length: 199
# MERS0_SI1019
# True length: 160, alignment length: 160
# MERS0_SI1649
# True length: 82, alignment length: 83
# MERS0_SI497
# True length: 239, alignment length: 239
# MERS0_SX119
# True length: 138, alignment length: 138
# MERS0_SX209
# True length: 141, alignment length: 141
# MERS0_SX299
# True length: 139, alignment length: 139
# MERS0_SX29
# True length: 122, alignment length: 123
# MERS0_SX389
# True length: 160, alignment length: 160
# MGJF0_SI1901
# True length: 154, alignment length: 154
# MGJF0_SI641
# True length: 261, alignment length: 241
# MGJF0_SI776
# True length: 88, alignment length: 88
# MGJF0_SX101
# True length: 182, alignment length: 165
# MGJF0_SX11
# True length: 79, alignment length: 79
# MGJF0_SX191
# True length: 121, alignment length: 121
# MGJF0_SX281
# True length: 172, alignment length: 156
# MGJF0_SX371
# True length: 167, alignment length: 167
# MGLB0_SI1534
# True length: 195, alignment length: 195
# MGLB0_SI2164
# True length: 65, alignment length: 66
# MGLB0_SI904
# True length: 185, alignment length: 186
# MGLB0_SX184
# True length: 113, alignment length: 113
# MGLB0_SX274
# True length: 126, alignment length: 126
# MGLB0_SX364
# True length: 201, alignment length: 201
# MGLB0_SX4
# True length: 121, alignment length: 121
# MGLB0_SX94
# True length: 121, alignment length: 121
# MGWT0_SI1539
# True length: 170, alignment length: 171
# MGWT0_SI2169
# True length: 263, alignment length: 263
# MGWT0_SI909
# True length: 274, alignment length: 275
# MGWT0_SX189
# True length: 164, alignment length: 164
# MGWT0_SX279
# True length: 228, alignment length: 228
# MGWT0_SX369
# True length: 173, alignment length: 173
# MGWT0_SX99
# True length: 184, alignment length: 184
# MGWT0_SX9
# True length: 175, alignment length: 175
# MJAR0_SI1988
# True length: 124, alignment length: 125
# MJAR0_SI2247
# True length: 67, alignment length: 67
# MJAR0_SI728
# True length: 248, alignment length: 248
# MJAR0_SX188
# True length: 125, alignment length: 125
# MJAR0_SX278
# True length: 182, alignment length: 183
# MJAR0_SX368
# True length: 167, alignment length: 167
# MJAR0_SX8
# True length: 123, alignment length: 123
# MJAR0_SX98
# True length: 96, alignment length: 96
# MJFC0_SI1033
# True length: 91, alignment length: 92
# MJFC0_SI1663
# True length: 119, alignment length: 119
# MJFC0_SI2293
# True length: 180, alignment length: 180
# MJFC0_SX133
# True length: 128, alignment length: 128
# MJFC0_SX223
# True length: 107, alignment length: 108
# MJFC0_SX313
# True length: 132, alignment length: 132
# MJFC0_SX403
# True length: 143, alignment length: 143
# MJFC0_SX43
# True length: 99, alignment length: 99
# MJSW0_SI1010
# True length: 232, alignment length: 232
# MJSW0_SI1640
# True length: 81, alignment length: 81
# MJSW0_SI2270
# True length: 121, alignment length: 121
# MJSW0_SX110
# True length: 144, alignment length: 144
# MJSW0_SX200
# True length: 126, alignment length: 126
# MJSW0_SX20
# True length: 176, alignment length: 176
# MJSW0_SX290
# True length: 180, alignment length: 180
# MJSW0_SX380
# True length: 203, alignment length: 203
# MMDB1_SI1625
# True length: 77, alignment length: 77
# MMDB1_SI2255
# True length: 174, alignment length: 174
# MMDB1_SI995
# True length: 213, alignment length: 213
# MMDB1_SX185
# True length: 116, alignment length: 116
# MMDB1_SX275
# True length: 134, alignment length: 134
# MMDB1_SX365
# True length: 181, alignment length: 181
# MMDB1_SX5
# True length: 82, alignment length: 82
# MMDB1_SX95
# True length: 146, alignment length: 146
# MMDM2_SI1452
# True length: 218, alignment length: 218
# MMDM2_SI1555
# True length: 109, alignment length: 109
# MMDM2_SI2082
# True length: 92, alignment length: 92
# MMDM2_SX102
# True length: 156, alignment length: 156
# MMDM2_SX12
# True length: 98, alignment length: 98
# MMDM2_SX192
# True length: 109, alignment length: 109
# MMDM2_SX282
# True length: 135, alignment length: 135
# MMDM2_SX372
# True length: 132, alignment length: 132
# MMJR0_SI1648
# True length: 238, alignment length: 238
# MMJR0_SI2166
# True length: 140, alignment length: 140
# MMJR0_SI2278
# True length: 135, alignment length: 135
# MMJR0_SX118
# True length: 147, alignment length: 147
# MMJR0_SX208
# True length: 174, alignment length: 174
# MMJR0_SX28
# True length: 119, alignment length: 119
# MMJR0_SX298
# True length: 169, alignment length: 169
# MMJR0_SX388
# True length: 188, alignment length: 188
# MMWH0_SI1089
# True length: 109, alignment length: 109
# MMWH0_SI1301
# True length: 190, alignment length: 190
# MMWH0_SI459
# True length: 255, alignment length: 255
# MMWH0_SX189
# True length: 130, alignment length: 130
# MMWH0_SX279
# True length: 187, alignment length: 187
# MMWH0_SX369
# True length: 123, alignment length: 123
# MMWH0_SX99
# True length: 158, alignment length: 158
# MMWH0_SX9
# True length: 89, alignment length: 89
# MPDF0_SI1542
# True length: 150, alignment length: 150
# MPDF0_SI2172
# True length: 155, alignment length: 155
# MPDF0_SI912
# True length: 137, alignment length: 137
# MPDF0_SX102
# True length: 193, alignment length: 193
# MPDF0_SX12
# True length: 110, alignment length: 110
# MPDF0_SX192
# True length: 114, alignment length: 114
# MPDF0_SX282
# True length: 149, alignment length: 149
# MPDF0_SX372
# True length: 140, alignment length: 140
# MRCS0_SI1223
# True length: 99, alignment length: 100
# MRCS0_SI1853
# True length: 217, alignment length: 218
# MRCS0_SI593
# True length: 136, alignment length: 136
# MRCS0_SX143
# True length: 133, alignment length: 134
# MRCS0_SX233
# True length: 120, alignment length: 120
# MRCS0_SX323
# True length: 133, alignment length: 133
# MRCS0_SX413
# True length: 170, alignment length: 170
# MRCS0_SX53
# True length: 134, alignment length: 134
# MREB0_SI1375
# True length: 219, alignment length: 220
# MREB0_SI2005
# True length: 248, alignment length: 248
# MREB0_SI745
# True length: 89, alignment length: 89
# MREB0_SX115
# True length: 125, alignment length: 126
# MREB0_SX205
# True length: 151, alignment length: 151
# MREB0_SX25
# True length: 108, alignment length: 108
# MREB0_SX295
# True length: 157, alignment length: 157
# MREB0_SX385
# True length: 92, alignment length: 92
# MRJM4_SI1489
# True length: 94, alignment length: 94
# MRJM4_SI2119
# True length: 111, alignment length: 111
# MRJM4_SI859
# True length: 216, alignment length: 216
# MRJM4_SX139
# True length: 134, alignment length: 134
# MRJM4_SX229
# True length: 72, alignment length: 72
# MRJM4_SX319
# True length: 124, alignment length: 125
# MRJM4_SX409
# True length: 151, alignment length: 151
# MRJM4_SX49
# True length: 127, alignment length: 127
# MRJR0_SI1182
# True length: 137, alignment length: 137
# MRJR0_SI1812
# True length: 148, alignment length: 148
# MRJR0_SI2313
# True length: 278, alignment length: 278
# MRJR0_SX102
# True length: 183, alignment length: 183
# MRJR0_SX12
# True length: 106, alignment length: 106
# MRJR0_SX192
# True length: 140, alignment length: 141
# MRJR0_SX282
# True length: 167, alignment length: 167
# MRJR0_SX372
# True length: 156, alignment length: 156
# MROA0_SI1307
# True length: 121, alignment length: 121
# MROA0_SI1970
# True length: 206, alignment length: 207
# MROA0_SI677
# True length: 110, alignment length: 110
# MROA0_SX137
# True length: 166, alignment length: 166
# MROA0_SX227
# True length: 91, alignment length: 92
# MROA0_SX317
# True length: 121, alignment length: 121
# MROA0_SX407
# True length: 173, alignment length: 173
# MROA0_SX47
# True length: 179, alignment length: 180
# MRTK0_SI1093
# True length: 142, alignment length: 143
# MRTK0_SI1723
# True length: 126, alignment length: 126
# MRTK0_SI1750
# True length: 233, alignment length: 233
# MRTK0_SX103
# True length: 117, alignment length: 118
# MRTK0_SX13
# True length: 116, alignment length: 116
# MRTK0_SX193
# True length: 113, alignment length: 114
# MRTK0_SX283
# True length: 158, alignment length: 158
# MRTK0_SX373
# True length: 132, alignment length: 133
# MRWS1_SI1130
# True length: 158, alignment length: 158
# MRWS1_SI1496
# True length: 140, alignment length: 140
# MRWS1_SI500
# True length: 196, alignment length: 196
# MRWS1_SX140
# True length: 151, alignment length: 152
# MRWS1_SX230
# True length: 160, alignment length: 160
# MRWS1_SX320
# True length: 163, alignment length: 164
# MRWS1_SX410
# True length: 141, alignment length: 141
# MRWS1_SX50
# True length: 161, alignment length: 161
# MTAA0_SI1285
# True length: 129, alignment length: 130
# MTAA0_SI1915
# True length: 249, alignment length: 250
# MTAA0_SI596
# True length: 102, alignment length: 102
# MTAA0_SX115
# True length: 148, alignment length: 149
# MTAA0_SX205
# True length: 167, alignment length: 167
# MTAA0_SX25
# True length: 101, alignment length: 101
# MTAA0_SX295
# True length: 171, alignment length: 171
# MTAA0_SX385
# True length: 114, alignment length: 114
# MTDT0_SI1994
# True length: 222, alignment length: 222
# MTDT0_SI2254
# True length: 108, alignment length: 108
# MTDT0_SI994
# True length: 164, alignment length: 164
# MTDT0_SX184
# True length: 132, alignment length: 132
# MTDT0_SX274
# True length: 160, alignment length: 160
# MTDT0_SX364
# True length: 248, alignment length: 248
# MTDT0_SX4
# True length: 144, alignment length: 144
# MTDT0_SX94
# True length: 131, alignment length: 132
# MTEB0_SI1133
# True length: 153, alignment length: 153
# MTEB0_SI2064
# True length: 267, alignment length: 267
# MTEB0_SI503
# True length: 96, alignment length: 96
# MTEB0_SX143
# True length: 153, alignment length: 153
# MTEB0_SX233
# True length: 126, alignment length: 126
# MTEB0_SX323
# True length: 140, alignment length: 140
# MTEB0_SX413
# True length: 163, alignment length: 163
# MTEB0_SX53
# True length: 140, alignment length: 140
# MTHC0_SI1015
# True length: 167, alignment length: 167
# MTHC0_SI1645
# True length: 141, alignment length: 141
# MTHC0_SI2275
# True length: 114, alignment length: 114
# MTHC0_SX115
# True length: 140, alignment length: 140
# MTHC0_SX205
# True length: 173, alignment length: 173
# MTHC0_SX25
# True length: 101, alignment length: 101
# MTHC0_SX295
# True length: 151, alignment length: 151
# MTHC0_SX385
# True length: 112, alignment length: 112
# MWJG0_SI1124
# True length: 230, alignment length: 231
# MWJG0_SI1754
# True length: 131, alignment length: 132
# MWJG0_SI494
# True length: 112, alignment length: 112
# MWJG0_SX134
# True length: 156, alignment length: 156
# MWJG0_SX224
# True length: 90, alignment length: 90
# MWJG0_SX314
# True length: 165, alignment length: 165
# MWJG0_SX404
# True length: 166, alignment length: 166
# MWJG0_SX44
# True length: 117, alignment length: 118
# Number of phonemes: 60
# ['h#', 'b', 'r', 'ih', 'kcl', 'k', 's', 'q', 'aa', 'axr', 'n', 'ao', 'l', 'tcl', 't', 'er', 'nx', 'ix', 'v', 'f', 'ae', 'sh', 'ow', 'dcl', 'd', 'uw', 'z', 'bcl', 'iy', 'th', 'ah', 'ax', 'm', 'y', 'ux', 'pcl', 'p', 'eh', 'hv', 'dx', 'epi', 'ey', 'ng', 'el', 'dh', 'ch', 'uh', 'oy', 'zh', 'jh', 'w', 'gcl', 'g', 'ay', 'en', 'hh', 'aw', 'em', 'pau', 'ax-h']

# %% [markdown]
# ### Extract forced alignment for ASL LibriSpeech

# %%
import os
from pathlib import Path
from textgrids import TextGrids

def is_inside(x1, x2):
    if x1[0] > x2[1] or x1[1] < x2[0]:
        return False
    return True

def read_librispeech_phone_alignment(phn_file):
    starts = []
    ends = []
    labels = []
    tg = TextGrids(phn_file) 
    for phn in tg["phones"]:
        starts.append(phn.xmin)
        ends.append(phn.xmax)
        labels.extend(phn.text)
    return starts, ends, labels

def map_phones_to_words(
        phn_starts, phn_ends, phn_labels,
        wrd_starts, wrd_ends, wrd_labels,
    ):
    mapped_starts = [[] for _ in range(len(wrd_starts))]
    mapped_ends = [[] for _ in range(len(wrd_starts))]
    mapped_labels = [[] for _ in range(len(wrd_starts))]
    for p_s, p_e, p_lbl in zip(phn_starts, phn_ends, phn_labels):
        for w_idx, (w_s, w_e, w_lbl) in enumerate(
            zip(wrd_starts, wrd_ends, wrd_labels)
        ):
            if is_inside((p_s, p_e), (w_s, w_e)):
                mapped_starts[w_idx].append(p_s)
                mapped_ends[w_idx].append(p_e)
                mapped_labels[w_idx].append(p_lbl)
    print(wrd_starts, wrd_ends, wrd_labels)
    print(mapped_starts, mapped_ends, mapped_labels)
    return mapped_starts, mapped_ends, mapped_labels

def extract_librispeech_phone_alignments(
        manifest_dir, 
        align_dir, 
        out_dir, 
        split, 
        frame_rate=0.02, 
        sr=16e3,
    ):
    manifest_dir = Path(manifest_dir)
    align_dir = Path(align_dir)
    out_dir = Path(out_dir)
    vocab = ['sil']
    with open(manifest_dir / f"{split}.jsonlines", "r") as f_wrd_ali,\
        open(manifest_dir / f"feat/{split}.lengths", "r") as f_len,\
        open(manifest_dir / f"{split}.phn", "w") as f_phn,\
        open(out_dir / f"{split}.src", "w") as f_src,\
        open(out_dir / f"{split}.src.txt", "w") as f_src_txt:
        sizes = list(map(int, f_len.read().strip().split("\n")))
        for line, size in zip(f_wrd_ali, sizes):
            utt = json.loads(line.rstrip("\n"))
            utt_id = utt["utterance_id"]
            wrd_starts = utt["begins"]
            wrd_ends = utt["ends"]
            wrd_labels = utt["labels"]
            parts = utt_id.split("_")
            align_subdir = "/".join(parts[:-1])
            align_name = f"{utt_id}.TextGrid"
            align_path = align_dir / align_subdir / align_name
            
            phn_starts, phn_ends, phn_labels = read_librispeech_phone_alignment(align_file)
            
            mapped_starts, mapped_ends, mapped_labels = map_phones_to_words(
                phn_starts, phn_ends, phn_labels,
                wrd_starts, wrd_ends, wrd_labels,
            )
            
            # Create phone-level transcript and frame-level phone sequence
            mapped_sequence = []
            mapped_int_sequence = []
            mapped_frame_sequence = []
            for starts, ends, labels in zip(mapped_starts, mapped_ends, mapped_labels):
                for start, end, phn in zip(starts, ends, labels):
                    if not phn in vocab:
                        vocab.append(phn)    
                    mapped_sequence.append(phn)
                    mapped_int_sequence.append(str(vocab.index(phn)))
                    s = start // int(frame_rate * sr)
                    e = end // int(frame_rate * sr)
                    mapped_frame_sequence.extend([phn]*(e-s))
            
            if size > len(mapped_int_sequence):
                gap = size - len(mapped_int_sequence)
                mapped_int_sequence.extend([0]*gap)
                mapped_frame_sequence.extend(['sil']*gap)
            elif size < len(mapped_int_sequence):
                mapped_int_sequence = mapped_int_sequence[:size]
                mapped_frame_sequence = mapped_frame_sequence[:size]
            assert len(mapped_int_sequence) == size
            
            f_src_txt.write(" ".join(mapped_frame_sequence)+"\n")
            f_src.write(" ".join(mapped_int_sequence)+"\n")
            f_phn.write(" ".join(mapped_sequence)+"\n")
